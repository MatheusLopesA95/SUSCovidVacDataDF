# %%
import pandas as pd

# %%
#Importando dataset
data=pd.read_csv('part-00000-ebc8a297-f0d5-4d27-8064-75cfa16cdf01.c000.csv', sep=';', on_bad_lines='skip')

#Creating Cod_Data Column 
Cod_Data = []
for string in data['vacina_dataAplicacao']:
    Cod_Data.append(string.replace('-', ''))
data['Cod_Data']=Cod_Data
# Out:
# C:\Users\mathe\AppData\Local\Temp\ipykernel_19004\1162614321.py:2: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('part-00000-ebc8a297-f0d5-4d27-8064-75cfa16cdf01.c000.csv', sep=';', on_bad_lines='skip')

# %%
data.head(5)
# Out:
#                                  document_id  \
# 0  c986114d-50e9-4526-8d25-60708253dd84-i0b0
# 1  6dc786cb-9e6b-4731-9fad-038f9a85faa5-i0b0
# 2  c98a3fab-5f05-42bb-8e31-02e25eb24b78-i0b0
# 3  6dc9f9c4-ab6d-4c4e-85b5-117c079b69c5-i0b0
# 4  c99154ea-9f55-4db2-b48f-f9839dd61187-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  714635020b805497c237bc9225bff1be71d881af33b963...            18.0
# 1  fa086cdc4637379e1994a0b538ff3e81f55dbf83930833...            91.0
# 2  5b8fd28a9780b85c8c02b53317b57ec218d00678357d2d...            23.0
# 3  eae7bf60ea6b60d078336188f15283b4aa4ce09f4221e7...             5.0
# 4  464a8bc7ab0a9e0cc2a3342868b99bd4267ea3f9b82683...            53.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2004-05-10                          M                     99.0
# 1              1930-02-20                          M                      3.0
# ...

# %%
data.groupby(['vacina_codigo', 'vacina_fabricante_nome']).count()
# Out:
#                                                          document_id  \
# vacina_codigo vacina_fabricante_nome
# 85            ASTRAZENECA/FIOCRUZ                             570934
#               FUNDACAO OSWALDO CRUZ                                3
# 86            SINOVAC/BUTANTAN                                431929
# 87            PFIZER                                         1073729
#               PFIZER MANUFACTURING BELGIUM NV - BELGICA            6
# 88            JANSSEN                                         166603
#               JANSSEN PHARMACEUTICA NV                             1
# 89            ASTRAZENECA                                      40962
# 98            SINOVAC                                             98
# 99            PFIZER - PEDI?TRICA                              11502
#               PFIZER - PEDIÁTRICA                               5852
#               PFIZER MANUFACTURING BELGIUM NV - BELGICA            1
# ...

# %%
data.loc[data['vacina_codigo']==88, 'vacina_fabricante_nome']='JANSSEN'
data.loc[data['vacina_codigo']==87, 'vacina_fabricante_nome']='PFIZER'
data.loc[data['vacina_codigo']==85, 'vacina_fabricante_nome']='ASTRAZENECA/FIOCRUZ'
data.loc[data['vacina_fabricante_nome']=='PFIZER MANUFACTURING BELGIUM NV - BELGICA', 'vacina_fabricante_nome']='PFIZER'
data.loc[data['vacina_fabricante_nome']=='PFIZER', 'vacina_codigo']=87
data.loc[data['vacina_fabricante_nome']=='PFIZER - PEDI?TRICA', 'vacina_fabricante_nome']='PFIZER - PEDIÁTRICA'
data.loc[data['vacina_fabricante_nome']=='Pendente Identifica??o', 'vacina_fabricante_nome']='Pendente Identificação'

# %%
data.groupby(['vacina_codigo', 'vacina_fabricante_nome']).count()
# Out:
#                                       document_id  paciente_id  \
# vacina_codigo vacina_fabricante_nome
# 85            ASTRAZENECA/FIOCRUZ          570937       570934
# 86            SINOVAC/BUTANTAN             431929       431928
# 87            PFIZER                      1073736      1073731
# 88            JANSSEN                      166604       166600
# 89            ASTRAZENECA                   40962        40961
# 98            SINOVAC                          98           98
# 99            PFIZER - PEDIÁTRICA           17354        17354
#               Pendente Identificação        26748        26747
#
#                                       paciente_idade  paciente_dataNascimento  \
# vacina_codigo vacina_fabricante_nome
# 85            ASTRAZENECA/FIOCRUZ             570934                   570934
# 86            SINOVAC/BUTANTAN                431928                   431928
# 87            PFIZER                         1073731                  1073731
# ...
